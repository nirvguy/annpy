# %%
import torch
from torch.nn import Module, Sigmoid, CrossEntropyLoss
from torch.utils.data import DataLoader
from torch.utils.data.dataset import Dataset
from torch import optim
from torch.autograd import Variable

import torchvision
from torchvision.datasets import MNIST

from torchvision import transforms


import matplotlib.pyplot as plt

from annpy.models.mlp import MLPClassifier
from torchtrainer import SupervisedTrainer
from torchtrainer.base import ValidationGranularity
from torchtrainer.meters import CategoricalAccuracy
from torchtrainer.callbacks import Logger

TRAIN = True
EPOCHS = 40
MODEL_PATH = 'models_saved'
USE_CUDA = True

# %%
data_transform = transforms.Compose([transforms.ToTensor(),
                                     transforms.Lambda(lambda x: x.view(x.numel()))])
training_dataset = MNIST('data', train=True, transform=data_transform, download=True)
data_loader_training = DataLoader(training_dataset,
                          batch_size=2048,
                          shuffle=True,
                          num_workers=4,
                           )

# %%
testing_dataset = MNIST('data', train=False, transform=data_transform, download=True)
data_loader_testing = DataLoader(testing_dataset,
                          batch_size=2048,
                          shuffle=True,
                          num_workers=4,
                           )

# %%
network=MLPClassifier([28*28, 800, 100], classes=range(10))

# %%
trainer = SupervisedTrainer(model=network,
                            criterion=CrossEntropyLoss(),
                            optimizer=optim.SGD(network.parameters(), lr=0.5),
                            acc_meters={'acc': CategoricalAccuracy()},
                            callbacks=[Logger()],
                            logging_frecuency=10,
                            validation_granularity=ValidationGranularity.AT_LOG)

# %%
if USE_CUDA:
    trainer.cuda()

# %%
trainer.train(data_loader_training,
              valid_dataloader=data_loader_testing,
              epochs=20)
# Out:
# epoch: 0/20,	step: 9/30,	train_loss: 2.306,	train_acc: 0.108,	val_loss: 2.301,	val_acc: 0.114
# epoch: 0/20,	step: 19/30,	train_loss: 2.302,	train_acc: 0.103,	val_loss: 2.293,	val_acc: 0.116
# epoch: 0/20,	step: 29/30,	train_loss: 2.292,	train_acc: 0.167,	val_loss: 2.309,	val_acc: 0.114
# epoch: 1/20,	step: 9/30,	train_loss: 2.289,	train_acc: 0.138,	val_loss: 2.286,	val_acc: 0.119
# epoch: 1/20,	step: 19/30,	train_loss: 2.280,	train_acc: 0.135,	val_loss: 2.272,	val_acc: 0.121
# epoch: 1/20,	step: 29/30,	train_loss: 2.268,	train_acc: 0.151,	val_loss: 2.268,	val_acc: 0.125
# epoch: 2/20,	step: 9/30,	train_loss: 2.254,	train_acc: 0.249,	val_loss: 2.240,	val_acc: 0.387
# epoch: 2/20,	step: 19/30,	train_loss: 2.230,	train_acc: 0.272,	val_loss: 2.213,	val_acc: 0.157
# epoch: 2/20,	step: 29/30,	train_loss: 2.192,	train_acc: 0.260,	val_loss: 2.182,	val_acc: 0.207
# epoch: 3/20,	step: 9/30,	train_loss: 2.182,	train_acc: 0.156,	val_loss: 2.166,	val_acc: 0.183
# epoch: 3/20,	step: 19/30,	train_loss: 2.108,	train_acc: 0.213,	val_loss: 2.068,	val_acc: 0.206
# epoch: 3/20,	step: 29/30,	train_loss: 2.079,	train_acc: 0.229,	val_loss: 2.060,	val_acc: 0.212
# epoch: 4/20,	step: 9/30,	train_loss: 1.959,	train_acc: 0.288,	val_loss: 1.874,	val_acc: 0.300
# epoch: 4/20,	step: 19/30,	train_loss: 1.820,	train_acc: 0.354,	val_loss: 1.767,	val_acc: 0.322
# epoch: 4/20,	step: 29/30,	train_loss: 1.816,	train_acc: 0.330,	val_loss: 1.540,	val_acc: 0.520
# epoch: 5/20,	step: 9/30,	train_loss: 1.608,	train_acc: 0.446,	val_loss: 1.482,	val_acc: 0.448
# epoch: 5/20,	step: 19/30,	train_loss: 1.452,	train_acc: 0.458,	val_loss: 1.386,	val_acc: 0.467
# epoch: 5/20,	step: 29/30,	train_loss: 1.395,	train_acc: 0.501,	val_loss: 1.201,	val_acc: 0.542
# epoch: 6/20,	step: 9/30,	train_loss: 1.308,	train_acc: 0.482,	val_loss: 1.205,	val_acc: 0.545
# epoch: 6/20,	step: 19/30,	train_loss: 1.161,	train_acc: 0.570,	val_loss: 1.122,	val_acc: 0.574
# epoch: 6/20,	step: 29/30,	train_loss: 1.104,	train_acc: 0.575,	val_loss: 1.038,	val_acc: 0.636
# epoch: 7/20,	step: 9/30,	train_loss: 1.021,	train_acc: 0.631,	val_loss: 1.020,	val_acc: 0.607
# epoch: 7/20,	step: 19/30,	train_loss: 0.974,	train_acc: 0.649,	val_loss: 0.944,	val_acc: 0.623
# epoch: 7/20,	step: 29/30,	train_loss: 0.872,	train_acc: 0.698,	val_loss: 0.837,	val_acc: 0.697
# epoch: 8/20,	step: 9/30,	train_loss: 0.823,	train_acc: 0.727,	val_loss: 0.780,	val_acc: 0.731
# epoch: 8/20,	step: 19/30,	train_loss: 0.766,	train_acc: 0.761,	val_loss: 0.793,	val_acc: 0.708
# epoch: 8/20,	step: 29/30,	train_loss: 0.794,	train_acc: 0.720,	val_loss: 0.719,	val_acc: 0.757
# epoch: 9/20,	step: 9/30,	train_loss: 0.740,	train_acc: 0.762,	val_loss: 0.777,	val_acc: 0.730
# epoch: 9/20,	step: 19/30,	train_loss: 0.713,	train_acc: 0.774,	val_loss: 0.638,	val_acc: 0.814
# epoch: 9/20,	step: 29/30,	train_loss: 0.647,	train_acc: 0.803,	val_loss: 0.703,	val_acc: 0.778
# epoch: 10/20,	step: 9/30,	train_loss: 0.666,	train_acc: 0.786,	val_loss: 0.601,	val_acc: 0.825
# epoch: 10/20,	step: 19/30,	train_loss: 0.626,	train_acc: 0.807,	val_loss: 0.594,	val_acc: 0.818
# epoch: 10/20,	step: 29/30,	train_loss: 0.596,	train_acc: 0.816,	val_loss: 0.601,	val_acc: 0.814
# epoch: 11/20,	step: 9/30,	train_loss: 0.596,	train_acc: 0.811,	val_loss: 0.539,	val_acc: 0.845
# epoch: 11/20,	step: 19/30,	train_loss: 0.540,	train_acc: 0.841,	val_loss: 0.540,	val_acc: 0.836
# epoch: 11/20,	step: 29/30,	train_loss: 0.534,	train_acc: 0.843,	val_loss: 0.533,	val_acc: 0.840
# epoch: 12/20,	step: 9/30,	train_loss: 0.535,	train_acc: 0.840,	val_loss: 0.503,	val_acc: 0.849
# epoch: 12/20,	step: 19/30,	train_loss: 0.527,	train_acc: 0.840,	val_loss: 0.527,	val_acc: 0.831
# epoch: 12/20,	step: 29/30,	train_loss: 0.523,	train_acc: 0.841,	val_loss: 0.492,	val_acc: 0.846
# epoch: 13/20,	step: 9/30,	train_loss: 0.507,	train_acc: 0.844,	val_loss: 0.511,	val_acc: 0.836
# epoch: 13/20,	step: 19/30,	train_loss: 0.517,	train_acc: 0.834,	val_loss: 0.476,	val_acc: 0.854
# epoch: 13/20,	step: 29/30,	train_loss: 0.488,	train_acc: 0.858,	val_loss: 0.456,	val_acc: 0.865
# epoch: 14/20,	step: 9/30,	train_loss: 0.468,	train_acc: 0.861,	val_loss: 0.455,	val_acc: 0.862
# epoch: 14/20,	step: 19/30,	train_loss: 0.477,	train_acc: 0.856,	val_loss: 0.461,	val_acc: 0.861
# epoch: 14/20,	step: 29/30,	train_loss: 0.466,	train_acc: 0.862,	val_loss: 0.449,	val_acc: 0.870
# epoch: 15/20,	step: 9/30,	train_loss: 0.446,	train_acc: 0.873,	val_loss: 0.425,	val_acc: 0.879
# epoch: 15/20,	step: 19/30,	train_loss: 0.453,	train_acc: 0.865,	val_loss: 0.419,	val_acc: 0.878
# epoch: 15/20,	step: 29/30,	train_loss: 0.422,	train_acc: 0.878,	val_loss: 0.415,	val_acc: 0.879
# epoch: 16/20,	step: 9/30,	train_loss: 0.425,	train_acc: 0.876,	val_loss: 0.411,	val_acc: 0.880
# epoch: 16/20,	step: 19/30,	train_loss: 0.423,	train_acc: 0.875,	val_loss: 0.406,	val_acc: 0.880
# epoch: 16/20,	step: 29/30,	train_loss: 0.422,	train_acc: 0.881,	val_loss: 0.403,	val_acc: 0.880
# epoch: 17/20,	step: 9/30,	train_loss: 0.415,	train_acc: 0.879,	val_loss: 0.396,	val_acc: 0.884
# epoch: 17/20,	step: 19/30,	train_loss: 0.407,	train_acc: 0.882,	val_loss: 0.405,	val_acc: 0.880
# epoch: 17/20,	step: 29/30,	train_loss: 0.436,	train_acc: 0.870,	val_loss: 0.485,	val_acc: 0.840
# epoch: 18/20,	step: 9/30,	train_loss: 0.428,	train_acc: 0.871,	val_loss: 0.384,	val_acc: 0.888
# epoch: 18/20,	step: 19/30,	train_loss: 0.397,	train_acc: 0.885,	val_loss: 0.382,	val_acc: 0.889
# epoch: 18/20,	step: 29/30,	train_loss: 0.397,	train_acc: 0.884,	val_loss: 0.386,	val_acc: 0.886
# epoch: 19/20,	step: 9/30,	train_loss: 0.398,	train_acc: 0.885,	val_loss: 0.376,	val_acc: 0.890
# epoch: 19/20,	step: 19/30,	train_loss: 0.386,	train_acc: 0.889,	val_loss: 0.370,	val_acc: 0.891
# epoch: 19/20,	step: 29/30,	train_loss: 0.379,	train_acc: 0.890,	val_loss: 0.382,	val_acc: 0.887

# %%
import matplotlib.pyplot as plt
trainer.history.step_plot('train_loss')
trainer.history.step_plot('val_loss')
plt.xlabel('iterations')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
trainer.history.step_plot('train_acc')
trainer.history.step_plot('val_acc')
plt.xlabel('iterations')
plt.ylabel('accuracy')
plt.show()
